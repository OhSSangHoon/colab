# %% [markdown]
# <a href="https://colab.research.google.com/github/OhSSangHoon/colab/blob/main/%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%A0%95%EC%A0%9C_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

ss_book4 = pd.read_csv('ss_book4.csv', low_memory=False)
ss_book4.head()
# Out:
#    번호                        도서명                         저자         출판사  발행년도  \
# 0   1                    급식왕 Go.  급식왕 원작;최재연 글;서후 콘티;구은미 그림  샌드박스스토리 키즈  2024
# 1   2  오무라이스 잼잼:웹툰과 함께 보는 사진 앨범.               조경규 글;방현선 사진        송송책방  2024
# 2   3                         플롯                     에이미 존스          드루  2024
# 3   4                    부모의 어휘력                        김종원       카시오페아  2024
# 4   5                그림자를 찾는 사람들                         이영       틈새의시간  2023
#
#             ISBN  세트 ISBN 부가기호    권   주제분류번호  도서권수  대출건수        등록일자
# 0  9791192504391      NaN    7   10    813.8     1     0  2024-08-27
# 1  9791190569743      NaN    0    2   594.04     1     0  2024-08-27
# 2  9791172173753      NaN  NaN  NaN      802     1     0  2024-08-27
# 3  9791168271999      NaN  NaN  NaN    598.1     1     0  2024-08-27
# 4  9791198387561      NaN  NaN  NaN  321.544     1     1  2024-08-27

# %%
ss_book4.isna().sum()
# Out:
# 번호              0
# 도서명            31
# 저자           2923
# 출판사          6400
# 발행년도          263
# ISBN            0
# 세트 ISBN    302988
# 부가기호        96880
# 권          262322
# 주제분류번호       5663
# 도서권수            0
# 대출건수            0
# 등록일자            0
# dtype: int64

# %%
ss_book5 = ss_book4.fillna({'부가기호':'없음'})
ss_book5.head()
# Out:
#    번호                        도서명                         저자         출판사  발행년도  \
# 0   1                    급식왕 Go.  급식왕 원작;최재연 글;서후 콘티;구은미 그림  샌드박스스토리 키즈  2024
# 1   2  오무라이스 잼잼:웹툰과 함께 보는 사진 앨범.               조경규 글;방현선 사진        송송책방  2024
# 2   3                         플롯                     에이미 존스          드루  2024
# 3   4                    부모의 어휘력                        김종원       카시오페아  2024
# 4   5                그림자를 찾는 사람들                         이영       틈새의시간  2023
#
#             ISBN  세트 ISBN 부가기호    권   주제분류번호  도서권수  대출건수        등록일자
# 0  9791192504391      NaN    7   10    813.8     1     0  2024-08-27
# 1  9791190569743      NaN    0    2   594.04     1     0  2024-08-27
# 2  9791172173753      NaN   없음  NaN      802     1     0  2024-08-27
# 3  9791168271999      NaN   없음  NaN    598.1     1     0  2024-08-27
# 4  9791198387561      NaN   없음  NaN  321.544     1     1  2024-08-27

# %%
ss_book4.replace({'부가기호':{np.nan:'없음'}, '발행년도':{'2024':'24'}}).head()
# Out:
#    번호                        도서명                         저자         출판사  발행년도  \
# 0   1                    급식왕 Go.  급식왕 원작;최재연 글;서후 콘티;구은미 그림  샌드박스스토리 키즈    24
# 1   2  오무라이스 잼잼:웹툰과 함께 보는 사진 앨범.               조경규 글;방현선 사진        송송책방    24
# 2   3                         플롯                     에이미 존스          드루    24
# 3   4                    부모의 어휘력                        김종원       카시오페아    24
# 4   5                그림자를 찾는 사람들                         이영       틈새의시간  2023
#
#             ISBN  세트 ISBN 부가기호    권   주제분류번호  도서권수  대출건수        등록일자
# 0  9791192504391      NaN    7   10    813.8     1     0  2024-08-27
# 1  9791190569743      NaN    0    2   594.04     1     0  2024-08-27
# 2  9791172173753      NaN   없음  NaN      802     1     0  2024-08-27
# 3  9791168271999      NaN   없음  NaN    598.1     1     0  2024-08-27
# 4  9791198387561      NaN   없음  NaN  321.544     1     1  2024-08-27

# %%
ss_book4.replace({'발행년도':{r'\d{2}(\d{2})': r'\1'}, '부가기호':{np.nan:'0'} , '권':{np.nan:'0'}, '세트 ISBN':{np.nan:'-'}}, regex=True).head()
#                       정규표현식    그룹    그룹출력
# Out:
#    번호                        도서명                         저자         출판사 발행년도  \
# 0   1                    급식왕 Go.  급식왕 원작;최재연 글;서후 콘티;구은미 그림  샌드박스스토리 키즈   24
# 1   2  오무라이스 잼잼:웹툰과 함께 보는 사진 앨범.               조경규 글;방현선 사진        송송책방   24
# 2   3                         플롯                     에이미 존스          드루   24
# 3   4                    부모의 어휘력                        김종원       카시오페아   24
# 4   5                그림자를 찾는 사람들                         이영       틈새의시간   23
#
#             ISBN 세트 ISBN 부가기호   권   주제분류번호  도서권수  대출건수        등록일자
# 0  9791192504391       -    7  10    813.8     1     0  2024-08-27
# 1  9791190569743       -    0   2   594.04     1     0  2024-08-27
# 2  9791172173753       -    0   0      802     1     0  2024-08-27
# 3  9791168271999       -    0   0    598.1     1     0  2024-08-27
# 4  9791198387561       -    0   0  321.544     1     1  2024-08-27

# %%
ss_book4['발행년도'][10]
# Out:
# '2024년'

# %%
invalid_number = ss_book4['발행년도'].str.contains('\D', na=True)
print(invalid_number.sum())
ss_book4[invalid_number].head()
# Out:
# 1635
#           번호                             도서명  \
# 10        11                          인간의 그물
# 11564  12039  북한의 섬 1: 함경북도, 함경남도, 황해남도 (추천)
# 13959  14556                     스너그들의 신기한 땅
# 15957  16577            (네모아저씨의) 페이퍼 블레이드 5,
# 17598  18235         달력으로 배우는 세계 역사 수업 (청소년)
#
#                                                       저자      출판사        발행년도  \
# 10                                                 권비영 외  한국소설가협회       2024년
# 11564                                                NaN      이어도         NaN
# 13959  베로니카 코산텔리 글;멜리사 카스트리욘 그림;송섬별 옮김;에드워드 오거스틴 와이크스...   주니어김영사         NaN
# 15957                                       네모아저씨 이원표 지음     슬로래빗  2022(2021)
# 17598                                             서민영 지음     글담출판         NaN
#
#                 ISBN  세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 10     9791170321026      NaN  NaN  NaN  813.7     1     0  2024-08-27
# 11564  9791191745191      NaN  NaN  NaN    NaN     1     2  2023-09-22
# ...

# %%
ss_book5 = ss_book4.replace({'발행년도':r'.*(\d{4}).*'}, r'\1', regex=True)
ss_book5[invalid_number].head()
# Out:
#           번호                             도서명  \
# 10        11                          인간의 그물
# 11564  12039  북한의 섬 1: 함경북도, 함경남도, 황해남도 (추천)
# 13959  14556                     스너그들의 신기한 땅
# 15957  16577            (네모아저씨의) 페이퍼 블레이드 5,
# 17598  18235         달력으로 배우는 세계 역사 수업 (청소년)
#
#                                                       저자      출판사  발행년도  \
# 10                                                 권비영 외  한국소설가협회  2024
# 11564                                                NaN      이어도   NaN
# 13959  베로니카 코산텔리 글;멜리사 카스트리욘 그림;송섬별 옮김;에드워드 오거스틴 와이크스...   주니어김영사   NaN
# 15957                                       네모아저씨 이원표 지음     슬로래빗  2021
# 17598                                             서민영 지음     글담출판   NaN
#
#                 ISBN  세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 10     9791170321026      NaN  NaN  NaN  813.7     1     0  2024-08-27
# 11564  9791191745191      NaN  NaN  NaN    NaN     1     2  2023-09-22
# ...

# %%
unknown_year = ss_book5['발행년도'].str.contains('\D', na=True)
print(unknown_year.sum())
# Out:
# 291

# %%
ss_book5[unknown_year][0:50]
# Out:
#             번호                                                도서명  \
# 11564    12039                     북한의 섬 1: 함경북도, 함경남도, 황해남도 (추천)
# 13959    14556                                        스너그들의 신기한 땅
# 17598    18235                            달력으로 배우는 세계 역사 수업 (청소년)
# 17844    18481                                        연결된 고통 (추천)
# 17986    18624                                          그리스 로마 신화
# 19542    20291                                               나이이즘
# 56870    61885                                             마법천자문.
# 58007    63091  (The) prenatal development of the human locomo...
# 58323    63410                                                리어왕
# 61820    67343                      석세스 에이징:노화의 잠재력을 끌어올리는 뇌과학의 힘
# 62399    68127                               (콕 집어 알려주는) 가정예배 가이드
# 63156    68966                          (스토리텔링 - 쉬운 영어로) 리딩 앤 플러스
# 73124    79701                         (사랑하는 아들과 딸을 위한) 스마트 발달동화
# ...

# %%
ss_book5.loc[unknown_year, '발행년도'] ='-1'
ss_book5=ss_book5.astype({'발행년도':'int32'})
ss_book5[unknown_year][0:50]
# Out:
#             번호                                                도서명  \
# 11564    12039                     북한의 섬 1: 함경북도, 함경남도, 황해남도 (추천)
# 13959    14556                                        스너그들의 신기한 땅
# 17598    18235                            달력으로 배우는 세계 역사 수업 (청소년)
# 17844    18481                                        연결된 고통 (추천)
# 17986    18624                                          그리스 로마 신화
# 19542    20291                                               나이이즘
# 56870    61885                                             마법천자문.
# 58007    63091  (The) prenatal development of the human locomo...
# 58323    63410                                                리어왕
# 61820    67343                      석세스 에이징:노화의 잠재력을 끌어올리는 뇌과학의 힘
# 62399    68127                               (콕 집어 알려주는) 가정예배 가이드
# 63156    68966                          (스토리텔링 - 쉬운 영어로) 리딩 앤 플러스
# 73124    79701                         (사랑하는 아들과 딸을 위한) 스마트 발달동화
# ...

# %%
ss_book5['발행년도'].gt(4000).sum()
# Out:
# 5

# %%
small_years = ss_book5['발행년도'].gt(0) & ss_book5['발행년도'].lt(1900)
ss_book5[small_years]
# Out:
#             번호                                            도서명  \
# 10928    11056         (The)furfins and the sparkly sleepover
# 21892    22680                                            나중에
# 30776    32512                         평생할 수있는 루틴만들기 66일 습관혁명
# 38469    41287                                   뮤즈, 글쓰기를 배우다
# 43698    46990                           지식 편의점: 문학, 인간의 생애 편
# 43699    46995                                   -10KG 밀가루 단식
# 43708    47005                       물은 H2O인가?(양장본 HardCover)
# 43709    47006                                         착각의 쓸모
# 43711    47015                             차이나는 클라스: 마음의 과학 편
# 43712    47016                          부자의 패턴(양장본 HardCover)
# 43715    47022                        너에게 속한 것(양장본 HardCover)
# 43716    47023               외모 강박: 나를 기쁘게 하지 못하는 몸(배반 인문학 1)
# 43717    47024                           미소우울증(양장본 HardCover)
# 43718    47027         10대와 통하는 기후 정의 이야기(10대를 위한 책도둑 시리즈 39)
# ...

# %%
import requests
from bs4 import BeautifulSoup
import re

def get_book_info(row):
  author = row['저자']
  pub = row['출판사']
  year = row['발행년도']
  url = 'https://search.kyobobook.co.kr/search?keyword={}&gbCode=TOT&target=total'

  r = requests.get(url.format(row['ISBN']))

  soup = BeautifulSoup(r.text, 'html.parser')

  try:
    if pd.isna(pub):
      pub=get_book_pub(row['ISBN'])
  except AttributeError:
      pass

  try:
    if pd.isna(author):
      author=get_book_author(row['ISBN'])
  except AttributeError:
      pass

  try:
    if year == -1:
      year=get_book_date(row['ISBN'])
  except AttributeError:
      pass

  return pub, author, year

# %%
def get_book_pub(isbn):
    url = 'https://search.kyobobook.co.kr/web/search?vPstrKeyWord={}&vPstrTab=PRODUCT'

    response = requests.get(url.format(isbn))

    soup = BeautifulSoup(response.text, 'html.parser')

    # 출판사와 출판년도를 포함하는 prod_publish 태그 추출
    pub_info = soup.find('div', attrs={'class':'prod_publish'})

    if pub_info:
        # 추출해보니 출판사명뿐만 아니라 날짜까지 함께 나와서 출판사명만 따로 추출
        # prod_publish 태그를 추출하지않고 바로 text 태그를 추출해도 되지만 span에도 text클래스가 있어서
        # 혹시나 다른 정보를 가져올까봐 prod_publish를 추출하고 그안의 text를 추출했음
        a_tag = pub_info.find('a', attrs={'class':'text'})
        if a_tag:
            return a_tag.get_text()
    else:
        return None

# %%
get_book_pub(9788977752467)
# Out:
# '철학과현실사'

# %%
def get_book_author(isbn):
    url = 'https://search.kyobobook.co.kr/web/search?vPstrKeyWord={}&vPstrTab=PRODUCT'

    response = requests.get(url.format(isbn))

    soup = BeautifulSoup(response.text, 'html.parser')

    # 저자 정보를 포함하는 prod_author 태그 추출
    author_info = soup.find('a', attrs={'class':'author'})

    if author_info:
      return author_info.get_text()
    else:
      return None

# %%
get_book_author(9788977752467)
# Out:
# '조정옥'

# %%
def get_book_date(isbn):
    url = 'https://search.kyobobook.co.kr/web/search?vPstrKeyWord={}&vPstrTab=PRODUCT'

    response = requests.get(url.format(isbn))

    soup = BeautifulSoup(response.text, 'html.parser')

    # 출판사 및 출판일자를 포함하는 prod_publish 태그 추출
    publish = soup.find('div', attrs={'class':'prod_publish'})

    if publish:
      # 위의 출판사와 마찬가지로 prod_publish 추출 후 date 추출
      date_info = soup.find('span', attrs={'class':'date'})

      year = re.findall(r'\d{4}', date_info.get_text()) # 정규표현식을 사용하여 연도만 추출 '2013'
      if year:
        return year[0]
      else:
        return None
    else:
      return None

# %%
get_book_date(9788977752467)
# Out:
# '1999'

# %%
na_rows = ss_book5['저자'].isna() \
 | ss_book5['출판사'].isna() | ss_book5['발행년도'].eq(-1)
updated_sample = ss_book5[na_rows].head(2).apply(get_book_info, axis=1, result_type='expand')
updated_sample.columns=['출판사','저자','발행년도']
updated_sample
# Out:
#       출판사    저자  발행년도
# 421   예문당   박정우  2024
# 602  문학동네  김진희   2022
