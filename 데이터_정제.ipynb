# %% [markdown]
# <a href="https://colab.research.google.com/github/OhSSangHoon/colab/blob/main/%EB%8D%B0%EC%9D%B4%ED%84%B0_%EC%A0%95%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

ss_df = pd.read_csv('suseong.csv', encoding='EUC-KR', low_memory=False)

ss_df.head()
# Out:
#    번호                        도서명                         저자         출판사  발행년도  \
# 0   1                    급식왕 Go.  급식왕 원작;최재연 글;서후 콘티;구은미 그림  샌드박스스토리 키즈  2024
# 1   2  오무라이스 잼잼:웹툰과 함께 보는 사진 앨범.               조경규 글;방현선 사진        송송책방  2024
# 2   3                         플롯                     에이미 존스          드루  2024
# 3   4                    부모의 어휘력                        김종원       카시오페아  2024
# 4   5                그림자를 찾는 사람들                         이영       틈새의시간  2023
#
#             ISBN  세트 ISBN 부가기호    권   주제분류번호  도서권수  대출건수        등록일자  \
# 0  9791192504391      NaN    7   10    813.8     1     0  2024-08-27
# 1  9791190569743      NaN    0    2   594.04     1     0  2024-08-27
# 2  9791172173753      NaN  NaN  NaN      802     1     0  2024-08-27
# 3  9791168271999      NaN  NaN  NaN    598.1     1     0  2024-08-27
# 4  9791198387561      NaN  NaN  NaN  321.544     1     1  2024-08-27
#
#    Unnamed: 13
# 0          NaN
# 1          NaN
# 2          NaN
# ...

# %%
ss_book = ss_df.loc[:, '번호':'등록일자']

ss_book.head()
# Out:
#    번호                        도서명                         저자         출판사  발행년도  \
# 0   1                    급식왕 Go.  급식왕 원작;최재연 글;서후 콘티;구은미 그림  샌드박스스토리 키즈  2024
# 1   2  오무라이스 잼잼:웹툰과 함께 보는 사진 앨범.               조경규 글;방현선 사진        송송책방  2024
# 2   3                         플롯                     에이미 존스          드루  2024
# 3   4                    부모의 어휘력                        김종원       카시오페아  2024
# 4   5                그림자를 찾는 사람들                         이영       틈새의시간  2023
#
#             ISBN  세트 ISBN 부가기호    권   주제분류번호  도서권수  대출건수        등록일자
# 0  9791192504391      NaN    7   10    813.8     1     0  2024-08-27
# 1  9791190569743      NaN    0    2   594.04     1     0  2024-08-27
# 2  9791172173753      NaN  NaN  NaN      802     1     0  2024-08-27
# 3  9791168271999      NaN  NaN  NaN    598.1     1     0  2024-08-27
# 4  9791198387561      NaN  NaN  NaN  321.544     1     1  2024-08-27

# %%
selected_columns = ss_df.columns != "Unnamed: 13"
ss_book = ss_df.loc[:, selected_columns]

ss_book.head()
# Out:
#    번호                        도서명                         저자         출판사  발행년도  \
# 0   1                    급식왕 Go.  급식왕 원작;최재연 글;서후 콘티;구은미 그림  샌드박스스토리 키즈  2024
# 1   2  오무라이스 잼잼:웹툰과 함께 보는 사진 앨범.               조경규 글;방현선 사진        송송책방  2024
# 2   3                         플롯                     에이미 존스          드루  2024
# 3   4                    부모의 어휘력                        김종원       카시오페아  2024
# 4   5                그림자를 찾는 사람들                         이영       틈새의시간  2023
#
#             ISBN  세트 ISBN 부가기호    권   주제분류번호  도서권수  대출건수        등록일자
# 0  9791192504391      NaN    7   10    813.8     1     0  2024-08-27
# 1  9791190569743      NaN    0    2   594.04     1     0  2024-08-27
# 2  9791172173753      NaN  NaN  NaN      802     1     0  2024-08-27
# 3  9791168271999      NaN  NaN  NaN    598.1     1     0  2024-08-27
# 4  9791198387561      NaN  NaN  NaN  321.544     1     1  2024-08-27

# %%
ss_book = ss_df.drop (['Unnamed: 13', '부가기호', '세트 ISBN'], axis=1)
ss_book.head()
# Out:
#    번호                        도서명                         저자         출판사  발행년도  \
# 0   1                    급식왕 Go.  급식왕 원작;최재연 글;서후 콘티;구은미 그림  샌드박스스토리 키즈  2024
# 1   2  오무라이스 잼잼:웹툰과 함께 보는 사진 앨범.               조경규 글;방현선 사진        송송책방  2024
# 2   3                         플롯                     에이미 존스          드루  2024
# 3   4                    부모의 어휘력                        김종원       카시오페아  2024
# 4   5                그림자를 찾는 사람들                         이영       틈새의시간  2023
#
#             ISBN    권   주제분류번호  도서권수  대출건수        등록일자
# 0  9791192504391   10    813.8     1     0  2024-08-27
# 1  9791190569743    2   594.04     1     0  2024-08-27
# 2  9791172173753  NaN      802     1     0  2024-08-27
# 3  9791168271999  NaN    598.1     1     0  2024-08-27
# 4  9791198387561  NaN  321.544     1     1  2024-08-27

# %%
ss_book2 = ss_book.drop([2,3])#axis  default값인 0은 행을 삭제
ss_book2.head()
# Out:
#    번호                        도서명                         저자         출판사  발행년도  \
# 0   1                    급식왕 Go.  급식왕 원작;최재연 글;서후 콘티;구은미 그림  샌드박스스토리 키즈  2024
# 1   2  오무라이스 잼잼:웹툰과 함께 보는 사진 앨범.               조경규 글;방현선 사진        송송책방  2024
# 4   5                그림자를 찾는 사람들                         이영       틈새의시간  2023
# 5   6                무엇도 아닌 모양으로                        김지원        카멜북스  2024
# 6   7                  르노뜨르 아카이브                   르노뜨르 동문회       비앤씨월드  2021
#
#             ISBN    권   주제분류번호  도서권수  대출건수        등록일자
# 0  9791192504391   10    813.8     1     0  2024-08-27
# 1  9791190569743    2   594.04     1     0  2024-08-27
# 4  9791198387561  NaN  321.544     1     1  2024-08-27
# 5  9791193497098  NaN      818     1     0  2024-08-27
# 6  9791186519479  NaN   594.71     1     0  2024-08-27

# %%
ss_book2 = ss_book[2:]
ss_book2.head()
# Out:
#    번호          도서명        저자    출판사  발행년도           ISBN    권   주제분류번호  도서권수  \
# 2   3           플롯    에이미 존스     드루  2024  9791172173753  NaN      802     1
# 3   4      부모의 어휘력       김종원  카시오페아  2024  9791168271999  NaN    598.1     1
# 4   5  그림자를 찾는 사람들        이영  틈새의시간  2023  9791198387561  NaN  321.544     1
# 5   6  무엇도 아닌 모양으로       김지원   카멜북스  2024  9791193497098  NaN      818     1
# 6   7    르노뜨르 아카이브  르노뜨르 동문회  비앤씨월드  2021  9791186519479  NaN   594.71     1
#
#    대출건수        등록일자
# 2     0  2024-08-27
# 3     0  2024-08-27
# 4     1  2024-08-27
# 5     0  2024-08-27
# 6     0  2024-08-27

# %%
selected_row = ss_df['출판사'] == '한빛미디어'
ss_book2 = ss_book[selected_row]
ss_book2.head()
# Out:
#         번호                                                도서명      저자    출판사  \
# 416    417                                             당근 마케팅     곽지운  한빛미디어
# 428    429                       100만 원 마케팅 (11회 브런치북 대상 수상작)     김건우  한빛미디어
# 513    514  쓸모 있는 AI 서비스 만들기:사전 학습 모델로 빠르게 구현하는 실전 AI 프로젝트...  김경환 지음  한빛미디어
# 680    681                                    처음 시작하는 FastAPI  빌 루바노빅  한빛미디어
# 1596  1597                                  혼자 공부하는 얄팍한 코딩 지식     고현민  한빛미디어
#
#       발행년도           ISBN    권  주제분류번호  도서권수  대출건수        등록일자
# 416   2024  9791169212564  NaN   325.5     1     0  2024-08-22
# 428   2024  9791169212618  NaN   325.5     1     0  2024-08-22
# 513   2024  9791169212557  NaN  004.73     1     1  2024-08-13
# 680   2024  9791169212649  NaN  005.13     1     0  2024-07-26
# 1596  2024  9791169212151  NaN   005.1     2     0  2024-07-16

# %%
selected_row = ss_df['대출건수'] > 100
ss_book2 = ss_book[selected_row]
ss_book2.head()
# Out:
#           번호                     도서명     저자     출판사  발행년도           ISBN    권  \
# 13451  13452             토지 1-20권 세트    박경리    다산책방  2023  9791130699455  NaN
# 21897  21898                      원씽  게리 켈러  비즈니스북스  2013  9788997575169  NaN
# 26957  26958       절교 가위:마루비 어린이문학 6    신은영     마루비  2021  9791191917055  NaN
# 26966  26967  불편한 편의점:40만부 기념 벚꽃 에디션    김호연   나무옆의자  2021  9791161571188  NaN
# 26972  26973    놀이 발명가:양장본 Hardcover    진은영     오늘책  2022  9791168251007  NaN
#
#        주제분류번호  도서권수  대출건수        등록일자
# 13451     NaN    20   103  2023-08-23
# 21897  325.04     5   123  2023-01-10
# 26957   813.8    10   206  2022-08-17
# 26966   813.7    10   450  2022-08-17
# 26972   813.8     5   111  2022-08-17

# %%
ss_book = ss_df.dropna(axis=1)

ss_book.head()
# Out:
#    번호           ISBN  도서권수  대출건수        등록일자
# 0   1  9791192504391     1     0  2024-08-27
# 1   2  9791190569743     1     0  2024-08-27
# 2   3  9791172173753     1     0  2024-08-27
# 3   4  9791168271999     1     0  2024-08-27
# 4   5  9791198387561     1     1  2024-08-27

# %%
ss_book = ss_df.dropna(axis=1, how='all')

ss_book.head()
# Out:
#    번호                        도서명                         저자         출판사  발행년도  \
# 0   1                    급식왕 Go.  급식왕 원작;최재연 글;서후 콘티;구은미 그림  샌드박스스토리 키즈  2024
# 1   2  오무라이스 잼잼:웹툰과 함께 보는 사진 앨범.               조경규 글;방현선 사진        송송책방  2024
# 2   3                         플롯                     에이미 존스          드루  2024
# 3   4                    부모의 어휘력                        김종원       카시오페아  2024
# 4   5                그림자를 찾는 사람들                         이영       틈새의시간  2023
#
#             ISBN  세트 ISBN 부가기호    권   주제분류번호  도서권수  대출건수        등록일자
# 0  9791192504391      NaN    7   10    813.8     1     0  2024-08-27
# 1  9791190569743      NaN    0    2   594.04     1     0  2024-08-27
# 2  9791172173753      NaN  NaN  NaN      802     1     0  2024-08-27
# 3  9791168271999      NaN  NaN  NaN    598.1     1     0  2024-08-27
# 4  9791198387561      NaN  NaN  NaN  321.544     1     1  2024-08-27

# %%
dup_rows = ss_book.duplicated(subset=['도서명','저자','ISBN'], keep=False)  #중복된 행 찾기 duplicated method
ss_book3 = ss_book[dup_rows]
ss_book3.head()
# Out:
#       번호                    도서명  \
# 38    39                배틀 급식왕.
# 303  304                마녀와의 7일
# 595  596                마녀와의 7일
# 613  614          (The)headache
# 614  615  (The)picture book man
#
#                                                     저자  \
# 38                                  급식왕 원작;서후 글;팀키즈 그림
# 303                                           히가시노 게이고
# 595                                           히가시노 게이고
# 613  written by Roderick Hunt;illustrated by Alex B...
# 614  written by Roderick Hunt;illustrated by Alex B...
#
#                             출판사  발행년도           ISBN       세트 ISBN 부가기호    권  \
# 38                     샌드박스네트워크  2022  9791197497384  9.791197e+12    7    1
# 303                        현대문학  2024  9791167902573           NaN  NaN  NaN
# 595                        현대문학  2024  9791167902573           NaN  NaN  NaN
# 613       OxfordUniversityPress  2011  9780198481034           NaN  NaN  NaN
# ...

# %%
count_df = ss_book[['도서명','저자','ISBN','권','대출건수']]
count_df.head()
# Out:
#                          도서명                         저자           ISBN    권  \
# 0                    급식왕 Go.  급식왕 원작;최재연 글;서후 콘티;구은미 그림  9791192504391   10
# 1  오무라이스 잼잼:웹툰과 함께 보는 사진 앨범.               조경규 글;방현선 사진  9791190569743    2
# 2                         플롯                     에이미 존스  9791172173753  NaN
# 3                    부모의 어휘력                        김종원  9791168271999  NaN
# 4                그림자를 찾는 사람들                         이영  9791198387561  NaN
#
#    대출건수
# 0     0
# 1     0
# 2     0
# 3     0
# 4     1

# %%
group_df = count_df.groupby(['도서명','저자','ISBN','권'], dropna=False) #그룹화 하기
loan_count = group_df.sum()
loan_count.head()
# Out:
#                                                                       대출건수
# 도서명                         저자                     ISBN          권
#  (1m로 뚝딱 만드는) 아이 옷과 소품      부티크사 지음;한수진 옮김         9788963057064 NaN    58
#  (2011-2012)프리미어리그 스카우팅 리포트 장원구;박찬하 공저             9788996522447 NaN    21
#  (2013)환경도서 독후감 공모전 수상작 모음집 환경부                    9788993460568 NaN     2
#  (검정고무신)한국사                 도래미 글;이우영 그림           9788961426459 5      84
#  (맨처음 배우는) 세상의 직업           엘레오노라 바르소티 글.그림;김태은 옮김 9788992924146 NaN   109

# %%
import pandas as pd

ss_book4 = pd.read_csv('ss_book4.csv', low_memory=False)

ss_df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-f982d689917e> in <cell line: 3>()
#       1 import pandas as pd
#       2
# ----> 3 ss_book4 = pd.read_csv('ss_book4.csv', low_memory=False)
#       4
#       5 ss_df.head()
#
# ...
